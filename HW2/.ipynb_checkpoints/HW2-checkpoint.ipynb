# %% [markdown]
# <h1><center>CSE 519 : Data Science Fundamentals</center></h1>
# <h2><center>HW-2 by Punit Mehta (ID: 111461860)</center></h2>

# %% [markdown]
# <h1><center>Task: 1</center></h1>

# %% [markdown]
#  Calculating Pearson Co-efficients for various pairs of columns

# %%
# Loading the properties file into a dataframe

import pandas as pd
import numpy as numpy

df = pd.read_csv('properties_2016.csv', low_memory=False) # TODO: Need to change these files' locations

# %% [markdown]
# Each of the following cell calculates values for pearson co-efficients. Note that there are some values for which pearson corelation value is pretty high (for example P6[0][1] = 0.673) which means that there is a positive corelation between total area of the structure and the assed value of it.
#
# Also, we can see that there is a negetive corelation between some features. For example, P15[0][1] = -0.0442 which means that the total garage area is decreasing year by year.

# %%
df_clean1 = df[numpy.isfinite(df['landtaxvaluedollarcnt'])]
df_clean1 = df_clean1[numpy.isfinite(df_clean1['finishedsquarefeet15'])]
P1 = numpy.corrcoef(df_clean1['landtaxvaluedollarcnt'], df_clean1['finishedsquarefeet15'])
print (P1[0][1])
# Out:
# 0.481456099382

# %%
df_clean2 = df[numpy.isfinite(df['landtaxvaluedollarcnt'])]
df_clean2 = df_clean2[numpy.isfinite(df_clean2['structuretaxvaluedollarcnt'])]
P2 = numpy.corrcoef(df_clean2['landtaxvaluedollarcnt'], df_clean2['structuretaxvaluedollarcnt'])
print (P2[0][1])
# Out:
# 0.480061286689

# %%
df_clean3 = df[numpy.isfinite(df['landtaxvaluedollarcnt'])]
df_clean3 = df_clean3[numpy.isfinite(df_clean3['numberofstories'])]
P3 = numpy.corrcoef(df_clean3['landtaxvaluedollarcnt'], df_clean3['numberofstories'])
print (P3[0][1])
# Out:
# 0.0912783410815

# %%
df_clean4 = df[numpy.isfinite(df['landtaxvaluedollarcnt'])]
df_clean4 = df_clean4[numpy.isfinite(df_clean4['garagetotalsqft'])]
P4 = numpy.corrcoef(df_clean4['landtaxvaluedollarcnt'], df_clean4['garagetotalsqft'])
print (P4[0][1])
# Out:
# 0.225069448138

# %%
df_clean5 = df[numpy.isfinite(df['landtaxvaluedollarcnt'])]
df_clean5 = df_clean5[numpy.isfinite(df_clean5['yearbuilt'])]
P5 = numpy.corrcoef(df_clean5['landtaxvaluedollarcnt'], df_clean5['yearbuilt'])
print (P5[0][1])
# Out:
# 0.0642493635147

# %%
df_clean6 = df[numpy.isfinite(df['finishedsquarefeet15'])]
df_clean6 = df_clean6[numpy.isfinite(df_clean6['structuretaxvaluedollarcnt'])]
P6 = numpy.corrcoef(df_clean6['finishedsquarefeet15'], df_clean6['structuretaxvaluedollarcnt'])
print (P6[0][1])
# Out:
# 0.673311081119

# %%
df_clean7 = df[numpy.isfinite(df['finishedsquarefeet15'])]
df_clean7 = df_clean7[numpy.isfinite(df_clean7['numberofstories'])]
P7 = numpy.corrcoef(df_clean7['finishedsquarefeet15'], df_clean7['numberofstories'])
print (P7[0][1])
# Out:
# 0.23527083927

# %%
df_clean8 = df[numpy.isfinite(df['finishedsquarefeet15'])]
df_clean8 = df_clean8[numpy.isfinite(df_clean8['garagetotalsqft'])]
P8 = numpy.corrcoef(df_clean8['finishedsquarefeet15'], df_clean8['garagetotalsqft'])
print (P8[0][1])
# Out:
# 0.0784350348521

# %%
df_clean9 = df[numpy.isfinite(df['finishedsquarefeet15'])]
df_clean9 = df_clean9[numpy.isfinite(df_clean9['yearbuilt'])]
P9 = numpy.corrcoef(df_clean9['finishedsquarefeet15'], df_clean9['yearbuilt'])
print (P9[0][1])
# Out:
# 0.105392764129

# %%
df_clean10 = df[numpy.isfinite(df['structuretaxvaluedollarcnt'])]
df_clean10 = df_clean10[numpy.isfinite(df_clean10['numberofstories'])]
P10 = numpy.corrcoef(df_clean10['structuretaxvaluedollarcnt'], df_clean10['numberofstories'])
print (P10[0][1])
# Out:
# 0.093677260415

# %%
df_clean11 = df[numpy.isfinite(df['structuretaxvaluedollarcnt'])]
df_clean11 = df_clean11[numpy.isfinite(df_clean11['garagetotalsqft'])]
P11 = numpy.corrcoef(df_clean11['structuretaxvaluedollarcnt'], df_clean11['garagetotalsqft'])
print (P11[0][1])
# Out:
# 0.400142540422

# %%
df_clean12 = df[numpy.isfinite(df['structuretaxvaluedollarcnt'])]
df_clean12 = df_clean12[numpy.isfinite(df_clean12['yearbuilt'])]
P12 = numpy.corrcoef(df_clean12['structuretaxvaluedollarcnt'], df_clean12['yearbuilt'])
print (P12[0][1])
# Out:
# 0.184826667185

# %%
df_clean13 = df[numpy.isfinite(df['numberofstories'])]
df_clean13 = df_clean13[numpy.isfinite(df_clean13['garagetotalsqft'])]
P13 = numpy.corrcoef(df_clean13['numberofstories'], df_clean13['garagetotalsqft'])
print (P13[0][1])
# Out:
# 0.0460196727679

# %%
df_clean14 = df[numpy.isfinite(df['numberofstories'])]
df_clean14 = df_clean14[numpy.isfinite(df_clean14['yearbuilt'])]
P14 = numpy.corrcoef(df_clean14['numberofstories'], df_clean14['yearbuilt'])
print (P14[0][1])
# Out:
# 0.311622506821

# %%
df_clean15 = df[numpy.isfinite(df['garagetotalsqft'])]
df_clean15 = df_clean15[numpy.isfinite(df_clean15['yearbuilt'])]
P15 = numpy.corrcoef(df_clean15['garagetotalsqft'], df_clean15['yearbuilt'])
print (P15[0][1])
# Out:
# -0.0442343759468

# %% [markdown]
# # Heatmap of the above caculated Pearson correlation coefficients

# %% [markdown]
# As we can see from the heatmap, the most positive correlation is between the total area and the value of the building on that area. Similarly, the most negative correaltion is between the garage area and year built of that property.

# %%
import seaborn as sns; sns.set()
# %matplotlib inline 

data = numpy.array([['abc','Land Tax Value ($)','Total Area (sqft)', 'Structure Tax Value ($)', '# of stories', 'Garage Area (sqft)', 'Year built'],
                ['Land Tax Value ($)',              1, P1[0][1], P2[0][1], P3[0][1] , P4[0][1],  P5[0][1]],
                ['Total Area (sqft)',        P1[0][1],        1, P6[0][1], P7[0][1] , P8[0][1],  P9[0][1]],
                 ['Structure Tax Value ($)', P2[0][1], P6[0][1],        1, P10[0][1], P11[0][1], P12[0][1]],
                 ['# of stories',            P3[0][1], P7[0][1], P10[0][1],        1, P13[0][1], P14[0][1]],
                 ['Garage Area (sqft)',      P4[0][1], P8[0][1], P11[0][1], P13[0][1],        1, P15[0][1]],
                 ['Year built',              P5[0][1], P9[0][1], P12[0][1], P14[0][1], P15[0][1], 1]]) 

x = data[1:,1:]
x = x.astype(numpy.float)

dataframe = pd.DataFrame(x,
                  index=data[1:,0],
                  columns=data[0,1:])

plt.rcParams['figure.figsize']=(15,10)
sns.heatmap(dataframe)

# %% [markdown]
# <h1><center>Task: 2</center></h1>

# %% [markdown]
# 1) As we can see from the line graph below, the price of the land had been increasing in the past till ~1935 and later it started increasing from around 1985. Note that we can't say that it started decreasing from 2016 or so just because of the construction of very expensive building (which are the data points at around 500000$ on y-axis and are kind of outliers for our visualization)

# %%
import matplotlib.pyplot as plt
df_clean = df[numpy.isfinite(df['landtaxvaluedollarcnt'])]
df_clean = df_clean[numpy.isfinite(df_clean['yearbuilt'])]
result = df_clean.groupby('yearbuilt').mean().reset_index()

result = result [result['yearbuilt'] > 1900] # for better visualization

plt.rcParams['figure.figsize']=(10,10)

ax = result[['yearbuilt','landtaxvaluedollarcnt']].plot(x='yearbuilt',linestyle='-', marker='o')
ax.set_xlabel("Year of construction", fontsize=20)
ax.set_ylabel("Total land value ($)", fontsize=20)

# %% [markdown]
# 2) Following is a graph of latitude verses longitude. As we can see that most of the places in the data are very nearby (forms a blue color filles areas) and there isn't any big outlier observed in terms of the values of lat/long.

# %%
import seaborn as sns
plt.figure(figsize = (10, 10))
sns.jointplot(x = df.latitude.values, y = df.longitude.values, size=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine>

# %% [markdown]
# 3) Following is a graph of the cities verses the number of bedrooms inside the apartments located in that city. We can observe that there are some cities for which maximum number of bedroom counts is very less and for some, there are apartments with even more than 9 bedrooms. However, the number of bedrooms is equally distibuted from 1 to 7 or 8 among all the major cities present in the dataset

# %%
import matplotlib.pyplot as plt
df_clean = df[numpy.isfinite(df['bedroomcnt'])]
result = df_clean[numpy.isfinite(df_clean['regionidcity'])]
result = result [result ['regionidcity'] < 50000] # Sampled here for better visulization
ax = result[['regionidcity','bedroomcnt']].plot.scatter('regionidcity', 'bedroomcnt')
ax.set_xlabel("City Ids", fontsize=20)
ax.set_ylabel("Total # of bedrooms", fontsize=20)

# %% [markdown]
# 4) Following is a graph of the total areas verses the number of bedrooms inside the apartments. As we can see that aparments having less area tend to have less number of bedrooms and vice versa.

# %%
import matplotlib.pyplot as plt
df_clean = df[numpy.isfinite(df['bedroomcnt'])]
result = df_clean[numpy.isfinite(df_clean['finishedsquarefeet15'])]
result = result [result ['bedroomcnt'] != 0] # Had to remove the properties with zero bedrooms for better visulizations
result = result [result ['finishedsquarefeet15'] < 25000] # Had to remove the outliers with zero bedrooms for better visulizations
ax = result[['finishedsquarefeet15','bedroomcnt']].plot.scatter('finishedsquarefeet15', 'bedroomcnt')
ax.set_xlabel("Total area", fontsize=20)
ax.set_ylabel("Total # of bedrooms", fontsize=20)

# %% [markdown]
# 5) Following is a graph of number of units verses the total area of the building. As we can see that the trend is positive and the area increases as the number of rooms (units) inside increase. However, there are some apartments with very few units and are very big and at the same time, there are structures with very large area and less number of units than the average.

# %%
import matplotlib.pyplot as plt
df_clean = df[numpy.isfinite(df['unitcnt'])]
result = df_clean[numpy.isfinite(df_clean['finishedsquarefeet15'])]
result = result [result ['unitcnt'] < 200] # for better visulizations
# result = result [result ['finishedsquarefeet15'] < 25000] # Had to remove the outliers with zero bedrooms for better visulizations
ax = result[['finishedsquarefeet15','unitcnt']].plot.scatter('unitcnt', 'finishedsquarefeet15')
ax.set_xlabel("Total # of units", fontsize=20)
ax.set_ylabel("Total area", fontsize=20)

# %% [markdown]
# 6) Following is a graph of year in which the building is constructed verses the average number of stories in a particular year. Observe that the average number of stories (datapoints on y-axis) is increasing year by year which is alined to the fact that the buildings which are made in late 2000s have lot more stories than the buildings that were constructed before.

# %%
# Average number of stories are increasing year by year

import matplotlib.pyplot as plt
df_clean = df[numpy.isfinite(df['yearbuilt'])]
result = df_clean[numpy.isfinite(df_clean['numberofstories'])]

plt.rcParams['figure.figsize']=(15,10)
result = result.groupby('yearbuilt').mean().reset_index()
result = result [result ['numberofstories'] < 2]
result = result [result ['yearbuilt'] > 1950]
ans = result[['numberofstories','yearbuilt']].plot.bar('yearbuilt', 'numberofstories')
ans.set_ylim(ymin=1)
ans.set_xlabel("Year of construction", fontsize=20)
ans.set_ylabel("Average # of stories", fontsize=20)

# %% [markdown]
# <h1><center>Task: 3</center> </h1>

# %% [markdown]
#    *Task on Linear Regression between various features and predicting the log-error*

# %%
# THIS CODE COMBINES THE ERROR-TABLE (training data) AND FEATURE TABLE (properties data) (OUTER JOIN)

train_df = pd.read_csv('train_2016_v2.csv') # TODO: Need to change these files' locations

parcel_value_list = train_df['parcelid']

df_filter_tained_parcel_ids = df[df.parcelid.isin(parcel_value_list)]

parcel_value_list2 = df_filter_tained_parcel_ids['parcelid']

train_df_2 = train_df[train_df.parcelid.isin(parcel_value_list2)]
sorted_df_filter_tained_parcel_ids = df_filter_tained_parcel_ids.sort_values(by='parcelid', ascending=1)

train_df_2 = train_df_2.drop_duplicates(['parcelid'], keep='last') #90150
sorted_train_df_2 = train_df_2.sort_values(by='parcelid', ascending=1)

train_df_joined = pd.merge(sorted_df_filter_tained_parcel_ids, sorted_train_df_2, on='parcelid', how='outer')

# %% [markdown]
# Following is the code and plot for the linear regression between the total assed value of the structure and the log error of zetimate. Here, 80% of the total traning data is used to train the model and rest 20% is used to test the model. Since the logerror is of zetimate and the total selling price, it makes sense to try the model with one feature as the total assed value of the strucutre and observe the results.
#
# Here, there are three experiements being done.
# (1) Linear regression with one feature (i.e. structuretaxvaluedollarcnt),
# (2)  Linear regression with one feature (i.e. finishedsquarefeet15),
# (3) Liner regression with two features (i.e. structuretaxvaluedollarcnt and finishedsquarefeet15)

# %%
# Exp:1 >> THIS IS THE CODE FOR LINEAR REGRESSION WITH ONE FEATURE (only 80% training data, 20% test data)

import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import ensemble
import matplotlib.pyplot as plt

train_df_joined_no_logerror_nan = train_df_joined[numpy.isfinite(train_df_joined['logerror'])]
train_df_joined_no_logerror_strctdollar_nan = train_df_joined_no_logerror_nan[numpy.isfinite(train_df_joined_no_logerror_nan['structuretaxvaluedollarcnt'])]

train_df_joined_no_logerror_strctdollar_nan.isnull().any()

train_x1_full = train_df_joined_no_logerror_strctdollar_nan.structuretaxvaluedollarcnt.values

slice_num = int(len(train_x1_full)*0.8)
train_x1 = train_x1_full[:slice_num]

train_x = train_x1.reshape(train_x1.shape[0], 1)

train_y_full = train_df_joined_no_logerror_strctdollar_nan.logerror.values
train_y = train_y_full[:slice_num]

# Creating test data for the ML model

test_x = train_x1_full[slice_num:]
test_x = test_x.reshape(test_x.shape[0], 1)

test_y = train_y_full[slice_num:]

# # Gradient boosting
# clf = ensemble.GradientBoostingRegressor(n_estimators=400, max_depth=5, min_samples_split=2, learning_rate = 0.1, loss = 'ls')
# clf.fit(train_x, train_y)
# clf.score(test_x, test_y)

# Linear Regression starts from here
regr = linear_model.LinearRegression()
regr.fit(train_x, train_y)

# The coefficients
print('Coefficients: \n', regr.coef_)

pred_y = regr.predict(test_x)

# Score
print ("The regression score is : %.9f" % regr.score(test_x, test_y))

# The mean squared error
print("Mean squared error: %.9f"
      % mean_squared_error(test_y, pred_y))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.9f' % r2_score(test_y, pred_y))


plt.rcParams['figure.figsize']=(15,10)
plt.xlabel("Structure Value ($)")
plt.ylabel("Log error")
plt.scatter(train_x, train_y,  color='black')
plt.plot(test_x, pred_y, color='blue', linewidth=3)
plt.show()
# Out:
# Coefficients:
#  [  1.56885668e-08]
# The regression score is : 0.000362804
# Mean squared error: 0.020691884
# Variance score: 0.000362804

# %%
# Exp:2 >> THIS IS THE CODE FOR LINEAR REGRESSION WITH ONE FEATURE (only 80% training data, 20% test data) - with finishedarea

import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

train_df_joined_no_logerror_nan = train_df_joined[numpy.isfinite(train_df_joined['logerror'])]
train_df_joined_no_logerror_strctdollar_nan = train_df_joined_no_logerror_nan[numpy.isfinite(train_df_joined_no_logerror_nan['finishedsquarefeet15'])]

train_x1_full = train_df_joined_no_logerror_strctdollar_nan.finishedsquarefeet15.values

slice_num = int(len(train_x1_full)*0.8)
train_x1 = train_x1_full[:slice_num]

train_x = train_x1.reshape(train_x1.shape[0], 1)


train_y_full = train_df_joined_no_logerror_strctdollar_nan.logerror.values
train_y = train_y_full[:slice_num]

regr_f1 = linear_model.LinearRegression()
regr_f1.fit(train_x, train_y)

# # The coefficients
print('Coefficients: \n', regr_f1.coef_)

test_x = train_x1_full[slice_num:]
test_x = test_x.reshape(test_x.shape[0], 1)

test_y = train_y_full[slice_num:]
pred_y = regr_f1.predict(test_x)

# # The mean squared error
print("Mean squared error: %.9f"
      % mean_squared_error(test_y, pred_y))

# # Explained variance score: 1 is perfect prediction
print('Variance score: %.9f' % r2_score(test_y, pred_y))


plt.rcParams['figure.figsize']=(15,10)
plt.xlabel("Structure Value ($)")
plt.ylabel("Log error")
plt.scatter(train_x, train_y,  color='black')
plt.plot(test_x, pred_y, color='blue', linewidth=3)
plt.show()
# Out:
# Coefficients:
#  [  4.96487044e-06]
# Mean squared error: 0.038174054
# Variance score: -0.003875227

# %%
# Exp:3 >> THIS IS THE CODE FOR LINEAR REGRESSION WITH TWO FEATURES (100% training data, 100% test data)

import numpy as np


train_df_joined_no_logerror_nan = train_df_joined[numpy.isfinite(train_df_joined['logerror'])]
train_df_joined_no_logerror_strctdollar_nan = train_df_joined_no_logerror_nan[numpy.isfinite(train_df_joined_no_logerror_nan['structuretaxvaluedollarcnt'])]
train_df_joined_no_logerror_strctdollar_sqft_nan = train_df_joined_no_logerror_strctdollar_nan[numpy.isfinite(train_df_joined_no_logerror_strctdollar_nan['finishedsquarefeet15'])]
train_df_joined_no_logerror_strctdollar_nan.isnull().any()

# train_df_joined_no_logerror_strctdollar_nan
train_x1 = train_df_joined_no_logerror_strctdollar_sqft_nan.structuretaxvaluedollarcnt.values
train_x2 = train_df_joined_no_logerror_strctdollar_sqft_nan.finishedsquarefeet15.values

train_x1_x2 = np.vstack((train_x1, train_x2)).T

train_y = train_df_joined_no_logerror_strctdollar_sqft_nan.logerror.values

regr = linear_model.LinearRegression()
regr.fit(train_x1_x2, train_y)

test_x1_x2 = train_x1_x2
test_y = train_y

pred_y = regr.predict(test_x1_x2)

# # The coefficients
print('Coefficients: \n', regr.coef_)

# # The mean squared error
print("Mean squared error: %.9f"
      % mean_squared_error(test_y, pred_y))

# # Explained variance score: 1 is perfect prediction
print('Variance score: %.9f' % r2_score(test_y, pred_y))
# Out:
# Coefficients:
#  [ -3.90061648e-08   6.28507393e-06]
# Mean squared error: 0.059602058
# Variance score: 0.000756824

# %% [markdown]
# As we can see from the above three experiements, models with only one feature is performing better than the model with two features. We will take the model with one feature (Exp-2 the one with finishedsquarefeet15 as a feature vector) and try to improve the same in the following tasks.
#
# *How well/badly does it work?*
# - The model in Exp:2 has a mean squared error of around 0.03 and a variance score of 0.003, which is not very good for linear regression models. The reason for such low values can be the not-exact-linear relationship between the x and y variables in question. We can see from the above figures that log-error and finishedsquarefeet15 are not following linear relationship in a substantial way.
#
# *Which variable is the most important one?*
# - As we can see from the above figures that the model with multiple features is not behaving the same or better than the model with a single feature. It seems that we should go ahead with single feature only. However, both the models with single feature are working almost with the same accuracy.

# %% [markdown]
# <h1><center>Task: 4</center> </h1>

# %% [markdown]
# *Following are the improvements in the model used above.*
#
# 1) Removed the NaN value from the training data,
# 2) Filter the outlier values from the training data,
# 3) Converting the model to polynomial regression y = (a*x)+(a*x^2) from linear regression,
# 4) Scaling the y-axis to f(y) = 10^y values, where the y value is 'finishedsquarefeet15'

# %%
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Improvement_0 : Removed the NaN value from the training data
train_df_joined_no_logerror_nan = train_df_joined[numpy.isfinite(train_df_joined['logerror'])]

# Improvement_1 : Filter the outlier values from the training data
train_df_joined_no_logerror_nan = train_df_joined_no_logerror_nan [train_df_joined_no_logerror_nan ['logerror'] < 0.5]

# Improvement_1 : Filter the outlier values from the training data
train_df_joined_no_logerror_yearbuilt_nan = train_df_joined_no_logerror_nan[numpy.isfinite(train_df_joined_no_logerror_nan['finishedsquarefeet15'])]
train_df_joined_no_logerror_yearbuilt_nan = train_df_joined_no_logerror_yearbuilt_nan [train_df_joined_no_logerror_yearbuilt_nan ['finishedsquarefeet15'] < 10000]


train_x1 = train_df_joined_no_logerror_yearbuilt_nan.finishedsquarefeet15.values


train_x1 = train_df_joined_no_logerror_yearbuilt_nan.finishedsquarefeet15.values

# Improvement_2 : Converting the model to polynomial regression y = (a*x)+(a*x^2) from linear regression
train_x2 = np.power(train_df_joined_no_logerror_yearbuilt_nan.finishedsquarefeet15.values, 2)
train_x = np.vstack((train_x1, train_x2)).T


train_y = train_df_joined_no_logerror_yearbuilt_nan.logerror.values

# Improvement_3 : Scaling the y-axis to f(y) = 10^y values, where the y value is 'finishedsquarefeet15'
train_y = np.power(10,train_y)

regr = linear_model.LinearRegression()
regr.fit(train_x, train_y)

# coefficients
print('Coefficients: \n', regr.coef_)

test_x = train_x
test_y = train_y

pred_y = regr.predict(test_x)

# The mean squared error
print("Mean squared error: %.9f"
      % mean_squared_error(np.log10(test_y), np.log10(pred_y)))

# variance score
print("Variance score: %.9f"
      % r2_score(np.log10(test_y), np.log10(pred_y)))


plt.rcParams['figure.figsize']=(15,10)
plt.xlabel("Structure Value ($)")
plt.ylabel("Log error")
plt.scatter(train_x1, train_y,  color='black')
plt.plot(train_x1, pred_y, color='blue', linewidth=3)
plt.show()
# Out:
# Coefficients:
#  [ -1.78490726e-05   5.09996576e-09]
# Mean squared error: 0.033158646
# Variance score: -0.028546581

# %% [markdown]
# *Which of your models minimizes the squared error?*
# - As calculated above, the improved version from the linear regression has mean squared error ~ 0.033158646, which almost at the same scale of previous model. However, we can see that the plot has now become a bit linear than before and we can hope to perform this better than the one used previously. (It actually performed better when submitted on kaggle and gave a better rank)

# %% [markdown]
# <h1><center>Task: 5</center> </h1>

# %% [markdown]
# Predict all the logerror for instances in file “sample_submission.csv”

# %%
import pandas as pd
import numpy as numpy

df = pd.read_csv('/Users/punit/Downloads/properties_2016.csv', low_memory=False) # TODO: Need to change these files' locations
df_sample_submission = pd.read_csv('/Users/punit/Downloads/sample_submission.csv', low_memory=False) # TODO: Need to change these files' locations

# %% [markdown]
# Following is the code snippet for creation of the file with logerrors required to submit on kaggle

# %%
# Creating submission.csv to upload on Kaggle

parcel_value_list = df_sample_submission['ParcelId']

df_sampled = df[df.parcelid.isin(parcel_value_list)] #2985217 
df_sampled_no_struct_val_nan = df_sampled[numpy.isfinite(df_sampled['finishedsquarefeet15'])]

test_x1 = df_sampled_no_struct_val_nan['finishedsquarefeet15']

test_x2 = np.power(df_sampled_no_struct_val_nan.finishedsquarefeet15.values, 2)
test_x = np.vstack((test_x1, test_x2)).T

# test_x.shape #190798, 2

pred_y_2016 = regr.predict(test_x)
pred_y_2016 = np.log10(pred_y_2016)

parcelids_non_nan = df_sampled_no_struct_val_nan['parcelid']

result_parcelids_non_nan_logerror = np.vstack((parcelids_non_nan, pred_y_2016)).T
result_parcelids_non_nan_logerror

raw_data = {'ParcelId': parcelids_non_nan, '201610': pred_y_2016}
df_result_parcelids_non_nan_logerror = pd.DataFrame(raw_data, columns = ['ParcelId', '201610'])

raw_data_2 = {'ParcelId': parcel_value_list}
df_sample_submission_only_parcelIds = pd.DataFrame(raw_data_2, columns = ['ParcelId'])

df_final_submission = pd.merge(df_result_parcelids_non_nan_logerror, df_sample_submission_only_parcelIds, on='ParcelId', how='outer')
df_final_submission = df_final_submission.fillna(0)
df_final_submission['201611'] = df_final_submission['201610']
df_final_submission['201612'] = df_final_submission['201610']
df_final_submission['201710'] = df_final_submission['201610']
df_final_submission['201711'] = df_final_submission['201610']
df_final_submission['201712'] = df_final_submission['201610']
df_final_submission.to_csv('submission.csv', sep=',', index=False)

# %% [markdown]
# Following is the score given by Kaggle. Rank is 2987 and score is 0.0662640

# %% [markdown]
# ![kaggle_result.png](attachment:kaggle_result.png)

# %% [markdown]
# <img src="kaggle_result.png",width=1000,height=1000>

# %% [markdown]
# <h1><center>Task: 6</center> </h1>

# %% [markdown]
# ~~ *A description of how the improved model works.* ~~
#
# The improved model is dependent on one feature of the input dataset which is finishedsquarefeet15. Here, finishedsquarefeet15 refers to the total area of the structure. Therefore, it was intutively interesting to see how the normal linear regression model works with this feature and since it gave almost positive results as described in the previous tasks. I went ahead and improved the same. Following are the improvements in the normal regression model.
#
# 0) To train the data properly, the NaN values (rows for which the interesting columns do not have the data) are removed.
#
# 1) I have filtered out the outliers from the training data to ensure that the model does not misfunction with the effect of some unusual results. I have removed the houses with very large areas and very large log-errors. Therefore, the training data is focused on the dataset that almost does not have expceptions and our model also does not have to dependend on these exceptions (i.e. give the results which are expected in the training data)
#
# 2) The logerrors in the input dataset are very small values and hence, it was difficult to completely distinguish the points on the graph and see the behaviour of it against the values on the x-axis (features) Also, the relationship between the log-error and the freatures does not seem to be strictly linear. And it makes sense to change the y-axis and observe the results. With this motivation, the y-axis in the improved model has been changed to f(y) = 10^y values, where the y value is 'finishedsquarefeet15' and ^ is a power operation
#
# 3) The model has been converted from a basic linear regression to the polynomial regression. Here the model is a quadratic one that follows the equation,
# - y = (a \* x) + (a \* x^2). Note that we can change the co-efficients (instead of 1) and can also change the maxium power (3, 4, 5 instead of 2)

# %% [markdown]
# ~~ *An evaluation of how well the improved model works.* ~~

# %% [markdown]
# Here we have conducted four experiments.
#
# (1) Linear regression with one feature (i.e. structuretaxvaluedollarcnt),
# (2) Linear regression with one feature (i.e. finishedsquarefeet15),
# (3) Liner regression with two features (i.e. structuretaxvaluedollarcnt and finishedsquarefeet15),
# (4) Polynomial regression with one feature (i.e. finishedsquarefeet15) without outliers and inverse-log axis

# %% [markdown]
# As noted in the previous tasks, (1) & (2) have mean squared error around 0.03 and (3) has 0.059602058. Our improved model has the mean squared error ~ 0.033158646. This way, it might seem that it didn't perform significantly better but when submitted on Kaggle, I saw a good amount of improvement in the score given by them.

# %% [markdown]
# The model I submitted on Kaggle has got the score of 0.0662640

# %% [markdown]
# ~~ *Any interesting experiences or surprises you had over the course of the experiments.* ~~

# %% [markdown]
# - While calculating the correlations, it was significantly changing with respect to the number of records. I had observed that for some records, it became even negative while taking more rows. This was pretty surprising as I expected the pearson correlation to behave in the similar manner (not drastically different) even if we increase the number of rows.
#
#
# - The baseline models that I implemented almost have the similar mean squared error with eachother with very insignificant diffence. However, when I submitted the results on Kaggle for these models, I got different scores and noticeable shifts in the ranks for different models. That, I feel, shows that means squared error is not an only creteria to decide which model works better.
#
#
# - The outliers matter much more while training the data. When I had the outliers in my data and I trained the linear regression model with that dataset, I didn't get the kind of accuracy that I was getting without outliers. This was really important for me to improve the score for my final model.
#
#
# - While reading about the housing problems and their promosed ML models online, I realised that there are many more ways to solve a housing problem and each solution has their own merits and demerits and works in specific scenarios. There is not a particular model/method to predict the housing prices (or logerror in this case) instead it's always the combination of various models and data cleaning and merging methods. This was an important learning.
